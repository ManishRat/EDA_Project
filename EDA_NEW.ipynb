# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_excel("C:/Users/Manish/OneDrive/Desktop/BTECH/Data Analytics/Datasheets/Superstore_USA5000.xlsx")
dataset.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
#
#   Profit  Quantity ordered new  Sales Order ID
# ...

# %%
dataset["Order Year"] = dataset["Order Date"].dt.year #In order to seperate the year from date and created a new column of name Order Year

# %%
dataset.shape
# Out:
# (4999, 25)

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     47
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# Order Year               0
# dtype: int64

# %%
#Here we filled the blank values by mean values of the data 
#by applying the below syntax and after that the missing values in "Product Base Margin" is 0

# %%
#Product Base Margin

# %%
plt.figure(figsize=(5,4))
sns.barplot(x = "Product Category",y="Product Base Margin", data=dataset ,estimator="sum")
plt.show()

# %%
#Sales on the basis of State

# %%
dataset["State or Province"].value_counts()[:5] #Top 5 state
# Out:
# State or Province
# California    677
# Texas         469
# Illinois      407
# New York      333
# Indiana       221
# Name: count, dtype: int64

# %%
#Order Year: In order to identify the counts of order on the various year

# %%
dataset["Order Year"].value_counts()
# Out:
# Order Year
# 2013    1622
# 2012    1192
# 2011    1150
# 2010    1035
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x = "Order Year", data = dataset)
plt.show()

# %%
#Product Category: in ordrer to identify the counts of products sold in various category

# %%
plt.figure(figsize=(5,4))
sns.countplot(x = "Product Category" ,data = dataset)
plt.show()

# %%
#Profit: In order to identify the count of profit under various product category

# %%
plt.figure(figsize=(5,4))
sns.barplot(x = "Product Category",y="Profit", data=dataset ,estimator="sum")
plt.show()

# %%
#Product Sub-Category
# we will make seperate graph for Office Supplies,Technology Product Category and Furniture

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = "Product Category" ,data = dataset[dataset["Product Category"]=="Office Supplies"],hue= "Product Sub-Category")
plt.show()

# %%
#Customer Segment

# %%
plt.figure(figsize=(7,4))
sns.countplot(x = "Customer Segment" ,data = dataset)
plt.show()

# %%
#Ship_Mode

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       3711
# Delivery Truck     691
# Express Air        597
# Name: count, dtype: int64

# %%
x = dataset["Ship Mode"].value_counts().index
y = dataset["Ship Mode"].value_counts().values

# %%
plt.figure(figsize=(5,4))  #Adjusted the figure of the piechart
plt.pie(y,labels=x , startangle=60 , autopct="%0.2f%%") #We rotated the angle of piechart by 60 degree and through autopct formula we converted to percentage form inside piechart
plt.legend(loc = 2)                 #we adjusted the position of legend
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x ="Ship Mode" , data = dataset , hue= "Product Category")
plt.show()

# %%
#Order Priority

# %%
dataset["Order Priority"].value_counts()
# Out:
# Order Priority
# Low              1052
# High             1044
# Not Specified     993
# Critical          963
# Medium            946
# Critical            1
# Name: count, dtype: int64

# %%
dataset["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
 dataset["Order Priority"] = dataset["Order Priority"].replace("Critical ","Critical")

# %%
#*In the above cell we found out that there are "Critical" and "Crictical " so in order to replace the one we used the syntax and after that we have only "critical"

# %%
plt.figure(figsize=(5,4))
sns.countplot(x = "Order Priority", data = dataset)
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priority.jpg")
plt.show()
